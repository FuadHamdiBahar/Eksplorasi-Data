# %%
from PIL import Image

img = Image.open('image/sample.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
print(img.size, img.format, img.mode)
# Out:
# (640, 427) JPEG RGB

# %%
new_width = 500
new_height = 300
img_resized = img.resize((new_width, new_height))
print('Original Image size', img.size)
print('New Image Size', img.size)
# Out:
# Original Image size (640, 427)
# New Image Size (640, 427)

# %%
angle = 90
img_rotated = img.rotate(angle, expand=True)
img_rotated.size
# Out:
# (427, 640)

# %%
img_flipped = img.transpose(Image.FLIP_LEFT_RIGHT)

# %%
img_flipped
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
left, top, right, bottom = 10, 10, 300, 200
img_cropped = img.crop((left, top, right, bottom))
img_cropped
# Out:
# <PIL.Image.Image image mode=RGB size=290x190>
