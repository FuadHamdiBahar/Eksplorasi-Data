# %%
import pandas as pd

# from .xlsx file
df = pd.read_excel('Data/contoh.xlsx', index_col='Unnamed: 0')
df.head()

# from .csv file
df = pd.read_csv('Data/contoh.csv', index_col='Unnamed: 0')
df.head()
# Out:
#                                  domains state-province         country  \
# 0                         ['rhul.ac.uk']            NaN  United Kingdom
# 1  ['myport.ac.uk', 'myport.port.ac.uk']            NaN  United Kingdom
# 2                  ['futureworks.ac.uk']            NaN  United Kingdom
# 3                         ['arts.ac.uk']            NaN  United Kingdom
# 4       ['abdn.ac.uk', 'aberdeen.ac.uk']            NaN  United Kingdom
#
#   alpha_two_code                       web_pages  \
# 0             GB          ['https://rhul.ac.uk']
# 1             GB   ['https://myport.port.ac.uk']
# 2             GB  ['https://futureworks.ac.uk/']
# 3             GB      ['https://www.arts.ac.uk']
# 4             GB      ['http://www.abdn.ac.uk/']
#
#                                   name
# 0  Royal Holloway University of London
# 1             University of Portsmouth
# 2                          Futureworks
# 3        University of the Arts London
# 4               University of Aberdeen

# %%
import pandas as pd
import requests

# from json
df = pd.read_json('Data/contoh.json')
df.head()

# from api
# retrieve data
url = 'http://universities.hipolabs.com/search?country=United+Kingdom'
response = requests.get(url)
# convert data to DataFrame
df = pd.DataFrame.from_dict(response.json())
df.head()
# Out:
#                              domains state-province         country  \
# 0                       [rhul.ac.uk]           None  United Kingdom
# 1  [myport.ac.uk, myport.port.ac.uk]           None  United Kingdom
# 2                [futureworks.ac.uk]           None  United Kingdom
# 3                       [arts.ac.uk]           None  United Kingdom
# 4       [abdn.ac.uk, aberdeen.ac.uk]           None  United Kingdom
#
#   alpha_two_code                     web_pages  \
# 0             GB          [https://rhul.ac.uk]
# 1             GB   [https://myport.port.ac.uk]
# 2             GB  [https://futureworks.ac.uk/]
# 3             GB      [https://www.arts.ac.uk]
# 4             GB      [http://www.abdn.ac.uk/]
#
#                                   name
# 0  Royal Holloway University of London
# 1             University of Portsmouth
# 2                          Futureworks
# 3        University of the Arts London
# 4               University of Aberdeen
