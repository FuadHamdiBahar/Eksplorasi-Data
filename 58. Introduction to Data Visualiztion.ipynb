# %%
import matplotlib.pyplot as plt

y = [300, 320, 315, 330, 350]
x = ['2000', '2001', '2002', '2003', '2004']

plt.plot(x, y, marker='o')
plt.title("Kenaikan Harga Rumah")
plt.ylabel("Juta")
plt.xlabel('Tahun')
# Out:
# Text(0.5, 0, 'Tahun')
